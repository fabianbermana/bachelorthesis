# %%
# standard imports
import time
import pickle

# external imports
import pandas as pd
import numpy as np
import sklearn as sk
from sklearn import metrics

# own imports
from evaluation import R2OS

# %%
# loading Goyal data
GoyalData_updated = pd.read_csv("GoyalData_2021.csv", thousands=',')

# starting and ending periods
start = 192612
end = 201612

# keep only necessary time periods
start_index = GoyalData_updated[GoyalData_updated['yyyymm'] == start].index[0]
end_index = GoyalData_updated[GoyalData_updated['yyyymm'] == end].index[0] + 1

data = GoyalData_updated

TRAIN_START = 192612
TRAIN_END = 195612
TEST_START = 195701
TEST_END = 201612

IND_TRAIN_START = data[data['yyyymm'] == TRAIN_START].index[0]
IND_TRAIN_END = data[data['yyyymm'] == TRAIN_END].index[0] + 1
IND_TEST_START = data[data['yyyymm'] == TEST_START].index[0]
IND_TEST_END = data[data['yyyymm'] == TEST_END].index[0] + 1

data
# Out:
#       yyyymm    Index      D12       E12       b/m     tbl     AAA     BAA  \
# 0     187101     4.44   0.2600    0.4000       NaN     NaN     NaN     NaN
# 1     187102     4.50   0.2600    0.4000       NaN     NaN     NaN     NaN
# 2     187103     4.61   0.2600    0.4000       NaN     NaN     NaN     NaN
# 3     187104     4.74   0.2600    0.4000       NaN     NaN     NaN     NaN
# 4     187105     4.86   0.2600    0.4000       NaN     NaN     NaN     NaN
# ...      ...      ...      ...       ...       ...     ...     ...     ...
# 1807  202108  4522.68  58.7913  169.8333  0.184756  0.0005  0.0255  0.0324
# 1808  202109  4307.54  59.2545  175.3700  0.193036  0.0004  0.0253  0.0323
# 1809  202110  4605.38  59.6354  182.8600  0.182389  0.0005  0.0268  0.0335
# 1810  202111  4567.00  60.0162  190.3500  0.189455  0.0005  0.0262  0.0328
# 1811  202112  4766.18  60.3971  197.8400  0.179786  0.0006  0.0265  0.0330
#
#          lty      ntis     Rfree      infl     ltr   corpr      svar  csp  \
# 0        NaN       NaN       NaN       NaN     NaN     NaN       NaN  NaN
# 1        NaN       NaN  0.004967       NaN     NaN     NaN       NaN  NaN
# 2        NaN       NaN  0.004525       NaN     NaN     NaN       NaN  NaN
# 3        NaN       NaN  0.004252       NaN     NaN     NaN       NaN  NaN
# 4        NaN       NaN  0.004643       NaN     NaN     NaN       NaN  NaN
# ...      ...       ...       ...       ...     ...     ...       ...  ...
# 1807  0.0128  0.014846  0.000000  0.002066 -0.0035 -0.0045  0.000602  NaN
# 1808  0.0137  0.015598  0.000000  0.002716 -0.0250 -0.0194  0.001393  NaN
# 1809  0.0158  0.013368  0.000000  0.008308  0.0051  0.0159  0.001151  NaN
# 1810  0.0156  0.015640  0.000100  0.004913  0.0210  0.0094  0.001327  NaN
# 1811  0.0146  0.012970  0.000000  0.003073 -0.0110 -0.0129  0.002518  NaN
#
#       CRSP_SPvw  CRSP_SPvwx
# 0           NaN         NaN
# 1           NaN         NaN
# 2           NaN         NaN
# 3           NaN         NaN
# 4           NaN         NaN
# ...         ...         ...
# 1807   0.030600    0.029205
# 1808  -0.046076   -0.047152
# 1809   0.070510    0.069627
# 1810  -0.007256   -0.008665
# 1811   0.043485    0.042285
#
# [1812 rows x 18 columns]

# %%
data_stocks = data.copy()[['yyyymm']]

data_stocks['EQPREM_+1'] = data.loc[:,'CRSP_SPvw'].shift(-1)

data_stocks['DP'] = np.log(data['D12'] / data['Index'])

data_stocks['DY'] = np.log(data['D12'] / data['Index'].shift(1))

data_stocks['DE'] = np.log(data['D12'] / data['E12'])

data_stocks['EP'] = np.log(data['E12'] / data['Index'])

data_stocks['SVAR'] = data['svar']

data_stocks['BM'] = data['b/m']

data_stocks['NTIS'] = data['ntis']

data_stocks['TBL'] = data['tbl']

data_stocks['LTY'] = data['lty']

data_stocks['LTR'] = data['ltr']

data_stocks['TMS'] = data['lty'] - data['tbl']

data_stocks['DFY'] = data['BAA'] - data['AAA']

data_stocks['DFR'] = data['corpr'] - data['ltr']

data_stocks['INFL'] = data['infl']

data_stocks = data_stocks.drop(columns=['LTY', 'DE'])

data_stocks.iloc[IND_TRAIN_START:IND_TEST_END,:].to_csv('data_e.csv', index=False)

data_stocks
# Out:
#       yyyymm  EQPREM_+1        DP        DY        EP      SVAR        BM  \
# 0     187101        NaN -2.837728       NaN -2.406945       NaN       NaN
# 1     187102        NaN -2.851151 -2.837728 -2.420368       NaN       NaN
# 2     187103        NaN -2.875302 -2.851151 -2.444519       NaN       NaN
# 3     187104        NaN -2.903111 -2.875302 -2.472328       NaN       NaN
# 4     187105        NaN -2.928112 -2.903111 -2.497329       NaN       NaN
# ...      ...        ...       ...       ...       ...       ...       ...
# 1807  202108  -0.046076 -4.342866 -4.314288 -3.282043  0.000602  0.184756
# 1808  202109   0.070510 -4.286281 -4.335018 -3.201224  0.001393  0.193036
# 1809  202110  -0.007256 -4.346731 -4.279873 -3.226260  0.001151  0.182389
# 1810  202111   0.043485 -4.331997 -4.340366 -3.177747  0.001327  0.189455
# 1811  202112        NaN -4.368359 -4.325671 -3.181842  0.002518  0.179786
#
#           NTIS     TBL     LTR     TMS     DFY     DFR      INFL
# 0          NaN     NaN     NaN     NaN     NaN     NaN       NaN
# 1          NaN     NaN     NaN     NaN     NaN     NaN       NaN
# 2          NaN     NaN     NaN     NaN     NaN     NaN       NaN
# 3          NaN     NaN     NaN     NaN     NaN     NaN       NaN
# 4          NaN     NaN     NaN     NaN     NaN     NaN       NaN
# ...        ...     ...     ...     ...     ...     ...       ...
# 1807  0.014846  0.0005 -0.0035  0.0123  0.0069 -0.0010  0.002066
# 1808  0.015598  0.0004 -0.0250  0.0133  0.0070  0.0056  0.002716
# 1809  0.013368  0.0005  0.0051  0.0153  0.0067  0.0108  0.008308
# 1810  0.015640  0.0005  0.0210  0.0151  0.0066 -0.0116  0.004913
# 1811  0.012970  0.0006 -0.0110  0.0140  0.0065 -0.0019  0.003073
#
# [1812 rows x 14 columns]

# %%
from sklearn.preprocessing import StandardScaler

X = np.array(data_stocks.drop(columns=['yyyymm', 'EQPREM_+1']).iloc[IND_TRAIN_START:IND_TEST_END-1,:])
y = np.array(data_stocks.loc[:,['EQPREM_+1']].iloc[IND_TRAIN_START:IND_TEST_END-1,:]).flatten()

scaler = StandardScaler().fit(X)
X_scaled = scaler.transform(X)

X_scaled_train = X_scaled[0:360,:]
X_scaled_test = X_scaled[360:1080,:]
X_train = X[0:360,:]
X_test = X[360:1080,:]
y_train = y[0:360]
y_test = y[360:1080]

# %%
# historical average - base model
bmk = np.mean(y_train)
pred_bmk = np.array([bmk] * y_test.shape[0])

MSPE_bmk = sk.metrics.mean_squared_error(y_test, pred_bmk)
R2OS_bmk = R2OS(MSPE_bmk, MSPE_bmk)

print(MSPE_bmk, R2OS_bmk)
# Out:
# 0.001761592109508611 0.0

# %% [markdown]
# ### CW Test

# %%
### DONE WITH LEAST SQUARES T SCORE ###

import statsmodels.api as sm

def CW_test(y_test, pred_bmk, pred_model):
    f = (y_test - pred_bmk) ** 2 - ((y_test - pred_model) ** 2 - (pred_bmk - pred_model) ** 2)
    model = sm.OLS(f,np.ones((f.shape[0], 1)), hasconst=True)
    results = model.fit()

    return results.tvalues[0]

# %%
### DONE WITH FORMULA IN THE PAPER ###

def CW_test(y_test, pred_bmk, pred_model):
    p = y_test.shape[0]
    e_1_hat_2 = (y_test - pred_bmk) ** 2
    e_2_hat_2 = (y_test - pred_model) ** 2
    adj = (pred_bmk - pred_model) ** 2
    
    f_hat = e_1_hat_2 - (e_2_hat_2 - adj)
    f_bar = np.sum(f_hat) / p
    
    return (p ** 0.5) * f_bar / (np.var(f_hat - f_bar, ddof=1) ** 0.5)

# %% [markdown]
# ### Expanding Window - Single Thread

# %%
from sklearn.linear_model import LinearRegression, LassoCV, ElasticNetCV
from sklearn.model_selection import TimeSeriesSplit
from sklearn import metrics

def expanding_window(X_train, X_test, y_train, y_test, forecast_model, model_args=None):
    """
    parameters
    -----------
    X_train: 2-dimensional numpy array, independent variables used to train the forecast model
    X_test: 2-dimensional numpy array, independent variables used for forecasting
    y_train: 1-dimensional numpy array, dependent variable used to train the forecast model
    y_test: 1-dimensional numpy array, dependent variable to forecast
    forecast_model: python object, model used for forecasting. Make this object similar to the
    sklearn models, with a fit() and predict() function
    model_args: dict, arguments to pass when initializing the model
    """
    start_time = time.time()
    if model_args is None:
        model_args = {}
    n_periods = y_test.shape[0]
    pred_model = np.zeros((n_periods,))
    pred_bmk = np.zeros((n_periods,))
    
    # run a forecast for every test period
    for i in range(n_periods):
        print(f'{i+1}/{n_periods}', end='\r')
        
        X_scaler = StandardScaler().fit(X_train)
        X = X_scaler.transform(X_train)
        y = y_train.reshape(-1,1)
        y_scaler = StandardScaler().fit(y)
        y = y_scaler.transform(y).flatten()
        
        # forecasts of model
        model = forecast_model(**model_args).fit(X, y)
        pred = model.predict(X_scaler.transform(X_test[[i],:]))
        pred_model[i] = y_scaler.inverse_transform(pred)
        
        # forecasts of historical average
        bmk = np.mean(y_train)
        pred_bmk[i] = bmk
        
        # add new row to training data
        X_train = np.vstack([X_train, X_test[[i],:]])
        y_train = np.hstack([y_train, y_test[i]])
    
    print('')
    
    MSPE_model = metrics.mean_squared_error(y_test, pred_model)
    MSPE_bmk = metrics.mean_squared_error(y_test, pred_bmk)
    R2OS_val = R2OS(MSPE_model, MSPE_bmk)
    
    end_time = time.time()
    elapsed_time = end_time - start_time

    return {'out-of-sample R2': R2OS_val, 
            'MSPE_bmk': MSPE_bmk, 
            'MSPE_model': MSPE_model, 
            'pred_bmk': pred_bmk,
            'pred_model': pred_model,
            'elapsed time': elapsed_time}


cv = TimeSeriesSplit(n_splits=5)

# %%
results_expw_LinearRegression = expanding_window(X_train, X_test, y_train, y_test, LinearRegression, model_args={'fit_intercept': True})
display = ['out-of-sample R2', 'MSPE_bmk', 'MSPE_model', 'elapsed time']
for item in display:
    print(f'{item}: {results_expw_LinearRegression[item]}')
# Out:
# 720/720
# out-of-sample R2: -0.09479595117769124
# MSPE_bmk: 0.0017631590057930802
# MSPE_model: 0.0019302993408247479
# elapsed time: 3.346508502960205

# %%
print(CW_test(y_test, results_expw_LinearRegression['pred_bmk'], results_expw_LinearRegression['pred_model']))
# Out:
# -0.3989513594471251

# %%
results_expw_LassoCV = expanding_window(X_train, X_test, y_train, y_test, LassoCV, model_args={'cv': cv})
display = ['out-of-sample R2', 'MSPE_bmk', 'MSPE_model', 'elapsed time']
for item in display:
    print(f'{item}: {results_expw_LassoCV[item]}')
# Out:
# 78/720

# %%
print(CW_test(y_test, results_expw_LassoCV['pred_bmk'], results_expw_LassoCV['pred_model']))

# %%
results_expw_ElasticNetCV = expanding_window(X_train, X_test, y_train, y_test, ElasticNetCV, model_args={'cv': cv})
display = ['out-of-sample R2', 'MSPE_bmk', 'MSPE_model', 'elapsed time']
for item in display:
    print(f'{item}: {results_expw_ElasticNetCV[item]}')

# %%
print(CW_test(y_test, results_expw_ElasticNetCV['pred_bmk'], results_expw_ElasticNetCV['pred_model']))

# %% [markdown]
# ### AveW - Single Thread

# %%
import warnings
from sklearn.exceptions import ConvergenceWarning
warnings.filterwarnings("ignore", category=ConvergenceWarning)

def AveW(X_train, X_test, y_train, y_test, forecast_model, m, w_min, model_args=None):
    
    start_time = time.time()
    
    if model_args is None:
        model_args = {}
    
    n_periods = y_test.shape[0]
    pred_model = np.zeros((n_periods,))
    pred_bmk = np.zeros((n_periods,))
    
    # loop through all forecasting periods
    for j in range(n_periods):
        print(f'{j+1}/{n_periods}', end='\r')
        
        T = X_train.shape[0]
        single_preds = np.zeros((m,))

        # AveW part
        for i in range(1, m+1):
            # calculate size of window i
            w_i = int(w_min + (i - 1)/(m - 1) * (T - w_min)) - 1
            #print(w_i)
            # starting and ending index of window i
            start, end = T-1-w_i, T-1
            # print(f'start:{T-1-w_i}, end:{T-1}')

            X = X_train[start:end,:]
            X_scaler = StandardScaler().fit(X)
            X = X_scaler.transform(X)
            y = y_train[start:end].reshape(-1,1)
            y_scaler = StandardScaler().fit(y)
            y = y_scaler.transform(y).flatten()
            
            
            model = forecast_model(**model_args).fit(X, y)
            pred = model.predict(X_scaler.transform(X_test[[j],:]))
            single_preds[i-1] = y_scaler.inverse_transform(pred)
            
        pred_model[j] = np.mean(single_preds)
        
        # forecasts of historical average
        bmk = np.mean(y_train)
        pred_bmk[j] = bmk
        
        # add new row to training data
        X_train = np.vstack([X_train, X_test[[j],:]])
        y_train = np.hstack([y_train, y_test[j]])
    
    print('')
    
    MSPE_model = metrics.mean_squared_error(y_test, pred_model)
    MSPE_bmk = metrics.mean_squared_error(y_test, pred_bmk)
    R2OS_val = R2OS(MSPE_model, MSPE_bmk)
    
    end_time = time.time()
    elapsed_time = end_time - start_time

    return {'out-of-sample R2': R2OS_val, 
            'MSPE_bmk': MSPE_bmk, 
            'MSPE_model': MSPE_model, 
            'pred_bmk': pred_bmk,
            'pred_model': pred_model,
            'elapsed time': elapsed_time}

cv = TimeSeriesSplit(n_splits=5)

# %%
results_AveW_LinearRegression = AveW(X_train, X_test[0:,:], y_train, y_test[0:], 
                                     LinearRegression, m=10, w_min=240, model_args={'fit_intercept': True})
display = ['out-of-sample R2', 'MSPE_bmk', 'MSPE_model', 'elapsed time']
for item in display:
    print(f'{item}: {results_AveW_LinearRegression[item]}')

# %%
print(CW_test(y_test, results_AveW_LinearRegression['pred_bmk'], results_AveW_LinearRegression['pred_model']))

# %%
results_AveW_LassoCV = AveW(X_train, X_test[0:,:], y_train, y_test[0:],
           LassoCV, m=10, w_min=240, model_args={'cv': cv, 'max_iter':5000})
display = ['out-of-sample R2', 'MSPE_bmk', 'MSPE_model', 'elapsed time']
for item in display:
    print(f'{item}: {results_AveW_LassoCV[item]}')

# %%
results_AveW_ElasticNetCV = AveW(X_train, X_test[0:,:], y_train, y_test[0:], 
           ElasticNetCV, m=10, w_min=240, model_args={'cv': cv, 'max_iter':5000})
display = ['out-of-sample R2', 'MSPE_bmk', 'MSPE_model', 'elapsed time']
for item in display:
    print(f'{item}: {results_AveW_ElasticNetCV[item]}')

# %% [markdown]
# ### Parallel Expanding Window

# %%
from joblib import Parallel, delayed
from sklearn.linear_model import LinearRegression, LassoCV, ElasticNetCV
from sklearn.model_selection import TimeSeriesSplit
from sklearn import metrics

def expanding_window_parallel(X_train, X_test, y_train, y_test, forecast_model, model_args=None, workers=-1, verbosity=10):
    """
    DESCRIPTION
    -----------
    Produce 1-step ahead forecasts, trained with recursive expanding windows.
    Uses parallelization on multiple CPU cores to speed up the process.
    
    PARAMETERS
    -----------
    X_train: 2-dimensional numpy array, independent variables used to train the forecast model
    
    X_test: 2-dimensional numpy array, independent variables used for forecasting
    
    y_train: 1-dimensional numpy array, dependent variable used to train the forecast model
    
    y_test: 1-dimensional numpy array, dependent variable to forecast
    
    forecast_model: python object, model used for forecasting. Make this object similar to the
    
    sklearn models, with a fit() and predict() function
    
    model_args: dict, arguments to pass when initializing the model
    
    workers: int, how many processes are used. -1 denotes using all available logical processors
    """

    start_time = time.time()
    
    # if no model arguments, parse an empty dictionary
    if model_args is None:
        model_args = {}
        
    n_periods = y_test.shape[0]
    pred_model = np.zeros((n_periods,))
    pred_bmk = np.zeros((n_periods,))
    
    # function to produce recursive expanding window forecasts
    def ExpW_forecast(X_train, y_train, i):
        print(f'{i+1}/{n_periods}', end='\r')
        
        # take the correct subsets of the dataset
        X_train = np.vstack([X_train, X_test[:i,:]])
        y_train = np.hstack([y_train, y_test[:i]])
        
        # scale the data
        X_scaler = StandardScaler().fit(X_train)
        X = X_scaler.transform(X_train)
        y = y_train.reshape(-1,1)
        y_scaler = StandardScaler().fit(y)
        y = y_scaler.transform(y).flatten()
        
        # forecasts of model
        model = forecast_model(**model_args).fit(X, y)
        pred = model.predict(X_scaler.transform(X_test[[i],:]))
        
        # historical average forecast as the baseline
        bmk = np.mean(y_train)
        
        # return a tuple of the baseline and the expanding window forecasts
        return bmk, y_scaler.inverse_transform(pred)[0]
    
    # run the forecast models in parallel
    pred_pairs = Parallel(n_jobs=workers, backend='loky', verbose=verbosity) \
        (delayed(ExpW_forecast)(X_train, y_train, i) for i in range(n_periods))

    # split the prediction tuples
    for i, pred_pair in enumerate(pred_pairs):
        pred_bmk[i] = pred_pair[0]
        pred_model[i] = pred_pair[1]
    
    # calculate metrics
    MSPE_model = metrics.mean_squared_error(y_test, pred_model)
    MSPE_bmk = metrics.mean_squared_error(y_test, pred_bmk)
    R2OS_val = R2OS(MSPE_model, MSPE_bmk)
    
    end_time = time.time()
    elapsed_time = end_time - start_time

    return {'out-of-sample R2': R2OS_val, 
            'MSPE_bmk': MSPE_bmk, 
            'MSPE_model': MSPE_model, 
            'pred_bmk': pred_bmk,
            'pred_model': pred_model,
            'elapsed time': elapsed_time}


# needed for LassoCV and ElasticNetCV
cv = TimeSeriesSplit(n_splits=5)

# %%
results_expw_LinearRegression = expanding_window_parallel(X_train, X_test[0:], y_train, y_test[0:], 
                                                          LinearRegression, model_args=None)
display = ['out-of-sample R2', 'MSPE_bmk', 'MSPE_model', 'elapsed time']
for item in display:
    print(f'{item}: {results_expw_LinearRegression[item]}')
    
with open('forecast_results/results_expw_LinearRegression.pickle', 'wb') as file:
    pickle.dump(results_expw_LinearRegression, file)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.0120s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.0360s.) Setting batch_size=4.
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.0200s.) Setting batch_size=8.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.0280s.) Setting batch_size=16.
# [Parallel(n_jobs=-1)]: Done 136 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.0679s.) Setting batch_size=32.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1278s.) Setting batch_size=64.
# [Parallel(n_jobs=-1)]: Done 312 tasks      | elapsed:    0.2s
# out-of-sample R2: -0.09479595117769124
# MSPE_bmk: 0.0017631590057930802
# MSPE_model: 0.0019302993408247479
# elapsed time: 0.6271622180938721
# [Parallel(n_jobs=-1)]: Done 529 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 584 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 649 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 720 out of 720 | elapsed:    0.5s finished

# %%
results_expw_LassoCV = expanding_window_parallel(X_train, X_test[0:], y_train, y_test[0:], 
                                                 LassoCV, model_args={'cv': cv})
display = ['out-of-sample R2', 'MSPE_bmk', 'MSPE_model', 'elapsed time']
for item in display:
    print(f'{item}: {results_expw_LassoCV[item]}')
    
with open('forecast_results/results_expw_LassoCV.pickle', 'wb') as file:
    pickle.dump(results_expw_LassoCV, file)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:    4.9s
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:    5.4s
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=-1)]: Done 137 tasks      | elapsed:    8.5s
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:    9.1s
# [Parallel(n_jobs=-1)]: Done 173 tasks      | elapsed:   10.0s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:   10.8s
# [Parallel(n_jobs=-1)]: Done 213 tasks      | elapsed:   11.6s
# [Parallel(n_jobs=-1)]: Done 234 tasks      | elapsed:   12.4s
# [Parallel(n_jobs=-1)]: Done 257 tasks      | elapsed:   13.3s
# [Parallel(n_jobs=-1)]: Done 280 tasks      | elapsed:   14.2s
# [Parallel(n_jobs=-1)]: Done 305 tasks      | elapsed:   15.2s
# [Parallel(n_jobs=-1)]: Done 330 tasks      | elapsed:   16.0s
# [Parallel(n_jobs=-1)]: Done 357 tasks      | elapsed:   17.0s
# [Parallel(n_jobs=-1)]: Done 384 tasks      | elapsed:   18.0s
# [Parallel(n_jobs=-1)]: Done 413 tasks      | elapsed:   19.1s
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed:   20.2s
# [Parallel(n_jobs=-1)]: Done 473 tasks      | elapsed:   21.4s
# [Parallel(n_jobs=-1)]: Done 504 tasks      | elapsed:   22.4s
# [Parallel(n_jobs=-1)]: Done 537 tasks      | elapsed:   23.5s
# [Parallel(n_jobs=-1)]: Done 570 tasks      | elapsed:   24.6s
# [Parallel(n_jobs=-1)]: Done 605 tasks      | elapsed:   25.7s
# [Parallel(n_jobs=-1)]: Done 640 tasks      | elapsed:   26.8s
# [Parallel(n_jobs=-1)]: Done 677 tasks      | elapsed:   28.0s
# out-of-sample R2: -0.00023184786504271138
# MSPE_bmk: 0.0017631590057930802
# MSPE_model: 0.0017635677904443044
# elapsed time: 29.50590991973877
# [Parallel(n_jobs=-1)]: Done 720 out of 720 | elapsed:   29.4s finished

# %%
results_expw_ElasticNetCV = expanding_window_parallel(X_train, X_test[0:], y_train, y_test[0:], 
                                                      ElasticNetCV, model_args={'cv': cv})
display = ['out-of-sample R2', 'MSPE_bmk', 'MSPE_model', 'elapsed time']
for item in display:
    print(f'{item}: {results_expw_ElasticNetCV[item]}')
    
with open('forecast_results/results_expw_ElasticNetCV.pickle', 'wb') as file:
    pickle.dump(results_expw_ElasticNetCV, file)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=-1)]: Done 137 tasks      | elapsed:    6.2s
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=-1)]: Done 173 tasks      | elapsed:    7.7s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:    8.5s
# [Parallel(n_jobs=-1)]: Done 213 tasks      | elapsed:    9.4s
# [Parallel(n_jobs=-1)]: Done 234 tasks      | elapsed:   10.2s
# [Parallel(n_jobs=-1)]: Done 257 tasks      | elapsed:   11.1s
# [Parallel(n_jobs=-1)]: Done 280 tasks      | elapsed:   11.9s
# [Parallel(n_jobs=-1)]: Done 305 tasks      | elapsed:   12.9s
# [Parallel(n_jobs=-1)]: Done 330 tasks      | elapsed:   13.8s
# [Parallel(n_jobs=-1)]: Done 357 tasks      | elapsed:   14.7s
# [Parallel(n_jobs=-1)]: Done 384 tasks      | elapsed:   15.7s
# [Parallel(n_jobs=-1)]: Done 413 tasks      | elapsed:   16.9s
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed:   17.9s
# [Parallel(n_jobs=-1)]: Done 473 tasks      | elapsed:   19.0s
# [Parallel(n_jobs=-1)]: Done 504 tasks      | elapsed:   20.1s
# [Parallel(n_jobs=-1)]: Done 537 tasks      | elapsed:   21.3s
# [Parallel(n_jobs=-1)]: Done 570 tasks      | elapsed:   22.4s
# [Parallel(n_jobs=-1)]: Done 605 tasks      | elapsed:   23.6s
# [Parallel(n_jobs=-1)]: Done 640 tasks      | elapsed:   24.9s
# [Parallel(n_jobs=-1)]: Done 677 tasks      | elapsed:   26.0s
# out-of-sample R2: 1.6082268055495064e-05
# MSPE_bmk: 0.0017631590057930802
# MSPE_model: 0.0017631306501973247
# elapsed time: 27.55993390083313
# [Parallel(n_jobs=-1)]: Done 720 out of 720 | elapsed:   27.5s finished

# %% [markdown]
# ### Parallel AveW

# %%
import joblib
from joblib import Parallel, delayed
from sklearn.linear_model import LinearRegression, LassoCV, ElasticNetCV
from sklearn.model_selection import TimeSeriesSplit
from sklearn import metrics

import warnings
from sklearn.exceptions import ConvergenceWarning
warnings.filterwarnings("ignore", category=ConvergenceWarning)

def AveW_parallel(X_train, X_test, y_train, y_test, forecast_model, m, w_min, model_args=None, workers=-1, verbosity=10):
    """
    DESCRIPTION
    -----------
    Produce 1-step ahead forecasts, trained with recursive expanding windows.
    Uses parallelization on multiple CPU cores to speed up the process.
    
    PARAMETERS
    -----------
    X_train: 2-dimensional numpy array, independent variables used to train the forecast model
    
    X_test: 2-dimensional numpy array, independent variables used for forecasting
    
    y_train: 1-dimensional numpy array, dependent variable used to train the forecast model
    
    y_test: 1-dimensional numpy array, dependent variable to forecast
    
    forecast_model: python object, model used for forecasting. Make this object similar to the

    m: number of windows for AveW forecasting
    
    w_min: minimum AveW window size
    
    sklearn models, with a fit() and predict() function
    
    model_args: dict, arguments to pass when initializing the model
    
    workers: int, how many processes are used. -1 denotes using all available logical processors
    """
    
    start_time = time.time()
    
    # parse an empty dict as the additional arguments
    if model_args is None:
        model_args = {}
    
    n_periods = y_test.shape[0]
    
    # arrays to store forecasts
    pred_model = np.zeros((n_periods,))
    pred_bmk = np.zeros((n_periods,))
    
    # loop through all forecasting periods
    def AveW_forecast(X_train, y_train, j, m):
        print(f'{j+1}/{n_periods}', end='\r')
        # properly load the subsets for each point forecast
        X_train = np.vstack([X_train, X_test[:j,:]])
        y_train = np.hstack([y_train, y_test[:j]])
        
        T = X_train.shape[0]
        single_preds = np.zeros((m,))

        # AveW part
        for i in range(1, m+1):
            # calculate size of window i
            w_i = int(w_min + (i - 1)/(m - 1) * (T - w_min)) - 1

            # starting and ending index of window i
            start, end = T-1-w_i, T-1
            # print(f'start:{T-1-w_i}, end:{T-1}')

            # scale the data
            X = X_train[start:end,:]
            X_scaler = StandardScaler().fit(X)
            X = X_scaler.transform(X)
            y = y_train[start:end].reshape(-1,1)
            y_scaler = StandardScaler().fit(y)
            y = y_scaler.transform(y).flatten()
            
            # train model and predict
            model = forecast_model(**model_args).fit(X, y)
            pred = model.predict(X_scaler.transform(X_test[[j],:]))
            single_preds[i-1] = y_scaler.inverse_transform(pred)
        
        # historical average is the benchmark
        bmk = np.mean(y_train)

        # return tuple of hist. avg and AveW forecast
        return bmk, np.mean(single_preds)
    
    # run predictions with multiple processors
    pred_pairs = Parallel(n_jobs=workers, backend='loky', verbose=verbosity) \
        (delayed(AveW_forecast)(X_train, y_train, j, m) for j in range(n_periods))

    # split tuple of predictions
    for i, pred_pair in enumerate(pred_pairs):
        pred_bmk[i] = pred_pair[0]
        pred_model[i] = pred_pair[1]
    
    # calculate metrics
    MSPE_model = metrics.mean_squared_error(y_test, pred_model)
    MSPE_bmk = metrics.mean_squared_error(y_test, pred_bmk)
    R2OS_val = R2OS(MSPE_model, MSPE_bmk)
    
    end_time = time.time()
    elapsed_time = end_time - start_time

    return {'out-of-sample R2': R2OS_val, 
            'MSPE_bmk': MSPE_bmk, 
            'MSPE_model': MSPE_model, 
            'pred_bmk': pred_bmk,
            'pred_model': pred_model,
            'elapsed time': elapsed_time}


# needed for LassoCV and ElasticNetCV
cv = TimeSeriesSplit(n_splits=5)

# %%
results_AveW_LinearRegression = AveW_parallel(X_train, X_test[0:,:], y_train, y_test[0:], 
                                     LinearRegression, m=10, w_min=240, model_args={'fit_intercept': True})
display = ['out-of-sample R2', 'MSPE_bmk', 'MSPE_model', 'elapsed time']
for item in display:
    print(f'{item}: {results_AveW_LinearRegression[item]}')
    
with open('forecast_results/results_AveW_LinearRegression.pickle', 'wb') as file:
    pickle.dump(results_AveW_LinearRegression, file)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.0394s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1620s.) Setting batch_size=4.
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done  92 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 128 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=-1)]: Done 172 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=-1)]: Done 216 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done 268 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=-1)]: Done 320 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=-1)]: Done 380 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done 440 tasks      | elapsed:    5.4s
# [Parallel(n_jobs=-1)]: Done 508 tasks      | elapsed:    6.2s
# [Parallel(n_jobs=-1)]: Done 576 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=-1)]: Done 652 tasks      | elapsed:    8.0s
# out-of-sample R2: -0.04698292355780809
# MSPE_bmk: 0.0017631590057930802
# MSPE_model: 0.0018459973705825176
# elapsed time: 8.846430778503418
# [Parallel(n_jobs=-1)]: Done 720 out of 720 | elapsed:    8.7s finished

# %%
results_AveW_LassoCV = AveW_parallel(X_train, X_test[0:,:], y_train, y_test[0:],
           LassoCV, m=10, w_min=240, model_args={'cv': cv, 'max_iter':5000})
display = ['out-of-sample R2', 'MSPE_bmk', 'MSPE_model', 'elapsed time']
for item in display:
    print(f'{item}: {results_AveW_LassoCV[item]}')
    
with open('forecast_results/results_AveW_LassoCV.pickle', 'wb') as file:
    pickle.dump(results_AveW_LassoCV, file)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    8.3s
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   12.1s
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   14.7s
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:   18.5s
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:   21.1s
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:   26.0s
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:   29.8s
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed:   34.7s
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:   39.5s
# [Parallel(n_jobs=-1)]: Done 137 tasks      | elapsed:   46.1s
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:   53.0s
# [Parallel(n_jobs=-1)]: Done 173 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 213 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 234 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 257 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 280 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 305 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 330 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 357 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 384 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 413 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 473 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 504 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 537 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 570 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 605 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=-1)]: Done 640 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=-1)]: Done 677 tasks      | elapsed:  3.9min
# out-of-sample R2: 0.0012518531138231426
# MSPE_bmk: 0.0017631590057930802
# MSPE_model: 0.001760951789701513
# elapsed time: 252.27812671661377
# [Parallel(n_jobs=-1)]: Done 720 out of 720 | elapsed:  4.2min finished

# %%
results_AveW_ElasticNetCV = AveW_parallel(X_train, X_test[0:,:], y_train, y_test[0:], 
           ElasticNetCV, m=10, w_min=240, model_args={'cv': cv, 'max_iter':5000})
display = ['out-of-sample R2', 'MSPE_bmk', 'MSPE_model', 'elapsed time']
for item in display:
    print(f'{item}: {results_AveW_ElasticNetCV[item]}')
    
with open('forecast_results/results_AveW_ElasticNetCV.pickle', 'wb') as file:
    pickle.dump(results_AveW_ElasticNetCV, file)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    5.7s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   11.0s
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   13.4s
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:   16.9s
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:   19.4s
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:   24.4s
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:   28.6s
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed:   33.3s
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:   37.0s
# [Parallel(n_jobs=-1)]: Done 137 tasks      | elapsed:   42.9s
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:   47.8s
# [Parallel(n_jobs=-1)]: Done 173 tasks      | elapsed:   53.7s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:   58.6s
# [Parallel(n_jobs=-1)]: Done 213 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 234 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 257 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 280 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 305 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 330 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 357 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 384 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 413 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 473 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 504 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 537 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 570 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 605 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 640 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done 677 tasks      | elapsed:  3.7min
# out-of-sample R2: 0.0027540616533363593
# MSPE_bmk: 0.0017631590057930802
# MSPE_model: 0.001758303157186491
# elapsed time: 235.4264612197876
# [Parallel(n_jobs=-1)]: Done 720 out of 720 | elapsed:  3.9min finished

# %% [markdown]
# ### BMA

# %%
class BlankModel:
    """
    A blank forecast model. Used to ensure every subclass has
    all the required functions.
    """
    
    def __init__(self):
        self.fitted = False
        self.n_predictors = None

    ### -------------------------- ###
    
    def _check_fit_args(self, X_train, y_train):
        if self.fitted:
            raise Exception('Model is already fitted')
        if len(X_train.shape) != 2:
            raise ValueError('X_train has to be 2D array')
        if len(y_train.shape) != 1:
            raise ValueError('y_train has to be 1D array')
        if X_train.shape[0] != y_train.shape[0]:
            raise ValueError('X_train and y_train have different numbers of rows')
        if X_train.shape[1] <= 0:
            raise ValueError('X_train contains no predictors')
            
    def _check_predict_args(self, X_pred):
        if not self.fitted:
            raise Exception('Model is not fitted')
        if len(X_pred.shape) != 2:
            raise ValueError('X_pred has to be 2D array')
        if X_pred.shape[1] != self.n_predictors:
            raise ValueError('''X_pred does not contain the same number of predictors as
                             training data''')
        
    ### -------------------------- ###
        
    def fit(self, X_train, y_train):
        raise NotImplementedError()

    def predict(self, X_pred):
        raise NotImplementedError()

# %%
class BMA(BlankModel):
    """
    Object to produce 1-step ahead forecasts using 
    Bayesian Model Averaging
    """
    
    def __init__(self):
        super().__init__()

    def fit(self, X_train, y_train):
        self._check_fit_args(X_train, y_train)
        self.fitted = True
    
    def predict(self, X_pred):
        self._check_predict_args(X_pred)

# %%
import itertools
from sklearn.linear_model import LinearRegression, LassoCV, ElasticNetCV

class BMA(BlankModel):
    """
    Object to produce 1-step ahead forecasts using 
    Bayesian Model Averaging
    """
    
    def __init__(self):
        super().__init__()

    ### -------------------------- ###

    def _BIC(self, ls_model, X_train, y_train):
        T = X_train.shape[0]
        N = X_train.shape[1]
        fitted_y = ls_model.predict(X_train)
        resid = y_train - fitted_y
        sigma = np.var(resid, ddof=0)
        
        return T * np.log(sigma) + np.log(T) * N
    
    ### -------------------------- ###
    
    def fit(self, X_train, y_train):
        self._check_fit_args(X_train, y_train)
        self.n_predictors = X.shape[1]
        self.fitted = True
        
        # compute all combinations
        indices = list(range(0, self.n_predictors))
        self.combinations = []
        for n in range(1, self.n_predictors+1):
            self.combinations.extend(list(itertools.combinations(indices, n)))
            
        n_models = len(self.combinations)
            
        # compute linear models and bic
        ls_models = np.ndarray((n_models,), LinearRegression)
        ls_bic = np.zeros((n_models,))
        for i, combination in enumerate(self.combinations):
            ls_models[i] = LinearRegression(fit_intercept=False).fit(X_train[:,combination], y_train)
    
        def calc_bic(combinations, X_train, y_train):
            ls_bic = np.zeros((n_models,))
            for i, combination in enumerate(combinations):
                ls_bic[i] = self._BIC(ls_models[i], X_train[:,combination], y_train)
            return ls_bic
        
        ls_bic = calc_bic(self.combinations, X_train, y_train)
            
        self.ls_models = ls_models
        self.ls_bic = ls_bic
        
        def calculate_BMA_weights(ls_bic):
            weights_BMA = np.zeros((n_models,))
            for i in range(n_models):
                bic_i = ls_bic[i]
                denom = np.sum(np.exp(0.5 * (bic_i - ls_bic)))
                weights_BMA[i] = 1 / denom
                
            return weights_BMA
        
        self.weights_BMA = calculate_BMA_weights(self.ls_bic)
        
        return self
    
    def predict(self, X_pred):
        self._check_predict_args(X_pred)
        
        prediction = np.zeros((1,))
        n_models = len(self.ls_models)
        
        for i, combination in enumerate(self.combinations):
            prediction += self.weights_BMA[i] * self.ls_models[i].predict(X_pred[[0],combination].reshape(1,-1))
        
        return prediction

start = time.time()
m = BMA()
print(m.fit(X_train, y_train))
print(m.predict(X_test[[0],:]))
end = time.time()

print(end-start)
# Out:
# <__main__.BMA object at 0x000001EF32EBBC10>
# [0.00991009]
# 2.0211286544799805

# %%
results_expw_BMA = expanding_window_parallel(X_train, X_test[0:], y_train, y_test[0:], 
                    BMA, model_args=None, verbosity=100)
display = ['out-of-sample R2', 'MSPE_bmk', 'MSPE_model', 'elapsed time']
for item in display:
    print(f'{item}: {results_expw_BMA[item]}')
    
with open('forecast_results/results_expw_BMA.pickle', 'wb') as file:
    pickle.dump(results_expw_BMA, file)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    5.2s
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    8.0s
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:    8.1s
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:    8.1s
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   11.0s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:   11.0s
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:   11.1s
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:   11.1s
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:   14.5s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:   14.6s
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:   14.6s
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:   14.7s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   17.8s
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:   17.8s
# [Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed:   17.9s
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed:   18.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:   21.3s
# [Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed:   21.3s
# [Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed:   21.3s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   21.6s
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:   24.7s
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:   24.7s
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:   24.8s
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:   25.1s
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed:   28.0s
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:   28.1s
# [Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed:   28.2s
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed:   28.4s
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   31.4s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   31.5s
# [Parallel(n_jobs=-1)]: Done  35 tasks      | elapsed:   31.6s
# [Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed:   31.8s
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:   35.1s
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed:   35.2s
# [Parallel(n_jobs=-1)]: Done  39 tasks      | elapsed:   35.4s
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:   35.6s
# [Parallel(n_jobs=-1)]: Done  41 tasks      | elapsed:   38.7s
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   38.7s
# [Parallel(n_jobs=-1)]: Done  43 tasks      | elapsed:   39.0s
# [Parallel(n_jobs=-1)]: Done  44 tasks      | elapsed:   39.3s
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed:   42.6s
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:   42.7s
# [Parallel(n_jobs=-1)]: Done  47 tasks      | elapsed:   43.2s
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed:   43.4s
# [Parallel(n_jobs=-1)]: Done  49 tasks      | elapsed:   46.7s
# [Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed:   46.8s
# [Parallel(n_jobs=-1)]: Done  51 tasks      | elapsed:   47.3s
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:   47.4s
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:   51.6s
# [Parallel(n_jobs=-1)]: Done  54 tasks      | elapsed:   51.6s
# [Parallel(n_jobs=-1)]: Done  55 tasks      | elapsed:   52.4s
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:   52.7s
# [Parallel(n_jobs=-1)]: Done  57 tasks      | elapsed:   56.1s
# [Parallel(n_jobs=-1)]: Done  58 tasks      | elapsed:   56.1s
# [Parallel(n_jobs=-1)]: Done  59 tasks      | elapsed:   56.6s
# [Parallel(n_jobs=-1)]: Done  60 tasks      | elapsed:   56.8s
# [Parallel(n_jobs=-1)]: Done  61 tasks      | elapsed:   59.6s
# [Parallel(n_jobs=-1)]: Done  62 tasks      | elapsed:   59.7s
# [Parallel(n_jobs=-1)]: Done  63 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done  65 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  66 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  67 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  68 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  69 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  70 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  71 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  72 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  73 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done  74 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done  75 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done  78 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done  79 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done  80 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done  81 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done  83 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done  84 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done  85 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done  86 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done  87 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done  88 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done  89 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done  91 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done  92 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done  93 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done  94 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done  95 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done  96 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done  97 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done  99 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 100 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 101 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 102 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 103 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 104 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 106 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 107 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 108 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 109 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 110 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 111 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 113 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 114 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 115 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 116 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 117 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 118 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 119 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 121 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 122 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 123 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 124 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 125 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 126 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 127 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 128 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 129 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 131 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 132 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 133 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 134 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 135 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 136 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 137 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 139 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 140 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 141 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 142 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 143 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 144 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 145 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 147 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 148 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 149 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 150 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 151 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 152 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 153 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 155 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 156 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 157 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 158 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 159 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 160 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 161 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 162 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 163 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 164 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 165 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 166 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 167 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 168 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 169 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 170 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 171 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 172 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 173 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 174 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 175 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 176 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 177 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 178 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 179 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 180 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 181 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 182 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 183 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 185 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 186 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 187 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 188 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 189 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 190 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 191 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 193 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 194 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 195 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 196 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 197 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 198 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 199 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done 200 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done 201 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done 202 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done 203 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done 204 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=-1)]: Done 206 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=-1)]: Done 207 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=-1)]: Done 208 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=-1)]: Done 209 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=-1)]: Done 210 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done 211 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done 212 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done 213 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done 214 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done 215 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done 216 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=-1)]: Done 217 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=-1)]: Done 218 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=-1)]: Done 219 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=-1)]: Done 220 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=-1)]: Done 221 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=-1)]: Done 222 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=-1)]: Done 223 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=-1)]: Done 224 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=-1)]: Done 225 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=-1)]: Done 226 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=-1)]: Done 227 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=-1)]: Done 228 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=-1)]: Done 229 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=-1)]: Done 230 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=-1)]: Done 231 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=-1)]: Done 232 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=-1)]: Done 233 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=-1)]: Done 234 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done 235 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done 236 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done 237 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done 238 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done 239 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done 240 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done 241 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=-1)]: Done 242 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=-1)]: Done 243 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=-1)]: Done 244 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=-1)]: Done 245 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=-1)]: Done 246 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=-1)]: Done 247 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=-1)]: Done 248 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=-1)]: Done 249 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=-1)]: Done 250 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=-1)]: Done 251 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=-1)]: Done 253 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=-1)]: Done 254 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=-1)]: Done 255 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=-1)]: Done 256 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=-1)]: Done 257 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=-1)]: Done 258 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=-1)]: Done 259 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=-1)]: Done 260 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=-1)]: Done 261 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=-1)]: Done 262 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=-1)]: Done 263 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=-1)]: Done 264 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=-1)]: Done 265 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=-1)]: Done 266 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=-1)]: Done 267 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=-1)]: Done 268 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=-1)]: Done 269 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=-1)]: Done 270 tasks      | elapsed:  4.6min
# [Parallel(n_jobs=-1)]: Done 271 tasks      | elapsed:  4.6min
# [Parallel(n_jobs=-1)]: Done 272 tasks      | elapsed:  4.6min
# [Parallel(n_jobs=-1)]: Done 273 tasks      | elapsed:  4.6min
# [Parallel(n_jobs=-1)]: Done 274 tasks      | elapsed:  4.6min
# [Parallel(n_jobs=-1)]: Done 275 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done 276 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done 277 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done 278 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done 279 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done 280 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done 281 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=-1)]: Done 282 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=-1)]: Done 283 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=-1)]: Done 284 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=-1)]: Done 285 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=-1)]: Done 286 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=-1)]: Done 287 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=-1)]: Done 288 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=-1)]: Done 289 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=-1)]: Done 290 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=-1)]: Done 291 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=-1)]: Done 292 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=-1)]: Done 293 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=-1)]: Done 294 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=-1)]: Done 295 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=-1)]: Done 296 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=-1)]: Done 297 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=-1)]: Done 298 tasks      | elapsed:  5.1min
# [Parallel(n_jobs=-1)]: Done 299 tasks      | elapsed:  5.1min
# [Parallel(n_jobs=-1)]: Done 300 tasks      | elapsed:  5.1min
# [Parallel(n_jobs=-1)]: Done 301 tasks      | elapsed:  5.1min
# [Parallel(n_jobs=-1)]: Done 302 tasks      | elapsed:  5.1min
# [Parallel(n_jobs=-1)]: Done 303 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=-1)]: Done 304 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=-1)]: Done 305 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=-1)]: Done 306 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=-1)]: Done 307 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=-1)]: Done 308 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=-1)]: Done 309 tasks      | elapsed:  5.3min
# [Parallel(n_jobs=-1)]: Done 310 tasks      | elapsed:  5.3min
# [Parallel(n_jobs=-1)]: Done 311 tasks      | elapsed:  5.3min
# [Parallel(n_jobs=-1)]: Done 312 tasks      | elapsed:  5.3min
# [Parallel(n_jobs=-1)]: Done 313 tasks      | elapsed:  5.3min
# [Parallel(n_jobs=-1)]: Done 314 tasks      | elapsed:  5.4min
# [Parallel(n_jobs=-1)]: Done 315 tasks      | elapsed:  5.4min
# [Parallel(n_jobs=-1)]: Done 316 tasks      | elapsed:  5.4min
# [Parallel(n_jobs=-1)]: Done 317 tasks      | elapsed:  5.4min
# [Parallel(n_jobs=-1)]: Done 318 tasks      | elapsed:  5.4min
# [Parallel(n_jobs=-1)]: Done 319 tasks      | elapsed:  5.4min
# [Parallel(n_jobs=-1)]: Done 320 tasks      | elapsed:  5.5min
# [Parallel(n_jobs=-1)]: Done 321 tasks      | elapsed:  5.5min
# [Parallel(n_jobs=-1)]: Done 322 tasks      | elapsed:  5.5min
# [Parallel(n_jobs=-1)]: Done 323 tasks      | elapsed:  5.5min
# [Parallel(n_jobs=-1)]: Done 324 tasks      | elapsed:  5.5min
# [Parallel(n_jobs=-1)]: Done 325 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=-1)]: Done 326 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=-1)]: Done 327 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=-1)]: Done 328 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=-1)]: Done 329 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=-1)]: Done 330 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=-1)]: Done 331 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=-1)]: Done 332 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=-1)]: Done 333 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=-1)]: Done 334 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=-1)]: Done 335 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=-1)]: Done 336 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=-1)]: Done 337 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=-1)]: Done 338 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=-1)]: Done 339 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=-1)]: Done 340 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=-1)]: Done 341 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=-1)]: Done 342 tasks      | elapsed:  5.9min
# [Parallel(n_jobs=-1)]: Done 343 tasks      | elapsed:  5.9min
# [Parallel(n_jobs=-1)]: Done 344 tasks      | elapsed:  5.9min
# [Parallel(n_jobs=-1)]: Done 345 tasks      | elapsed:  5.9min
# [Parallel(n_jobs=-1)]: Done 346 tasks      | elapsed:  5.9min
# [Parallel(n_jobs=-1)]: Done 347 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=-1)]: Done 348 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=-1)]: Done 349 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=-1)]: Done 350 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=-1)]: Done 351 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=-1)]: Done 352 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=-1)]: Done 353 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=-1)]: Done 354 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=-1)]: Done 355 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=-1)]: Done 356 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=-1)]: Done 357 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=-1)]: Done 358 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=-1)]: Done 359 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=-1)]: Done 360 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=-1)]: Done 361 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=-1)]: Done 362 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=-1)]: Done 363 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=-1)]: Done 364 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=-1)]: Done 365 tasks      | elapsed:  6.3min
# [Parallel(n_jobs=-1)]: Done 366 tasks      | elapsed:  6.3min
# [Parallel(n_jobs=-1)]: Done 367 tasks      | elapsed:  6.3min
# [Parallel(n_jobs=-1)]: Done 368 tasks      | elapsed:  6.3min
# [Parallel(n_jobs=-1)]: Done 369 tasks      | elapsed:  6.3min
# [Parallel(n_jobs=-1)]: Done 370 tasks      | elapsed:  6.4min
# [Parallel(n_jobs=-1)]: Done 371 tasks      | elapsed:  6.4min
# [Parallel(n_jobs=-1)]: Done 372 tasks      | elapsed:  6.4min
# [Parallel(n_jobs=-1)]: Done 373 tasks      | elapsed:  6.4min
# [Parallel(n_jobs=-1)]: Done 374 tasks      | elapsed:  6.4min
# [Parallel(n_jobs=-1)]: Done 375 tasks      | elapsed:  6.5min
# [Parallel(n_jobs=-1)]: Done 376 tasks      | elapsed:  6.5min
# [Parallel(n_jobs=-1)]: Done 377 tasks      | elapsed:  6.5min
# [Parallel(n_jobs=-1)]: Done 378 tasks      | elapsed:  6.5min
# [Parallel(n_jobs=-1)]: Done 379 tasks      | elapsed:  6.5min
# [Parallel(n_jobs=-1)]: Done 380 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=-1)]: Done 381 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=-1)]: Done 382 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=-1)]: Done 383 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=-1)]: Done 384 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=-1)]: Done 385 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=-1)]: Done 386 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=-1)]: Done 387 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=-1)]: Done 388 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=-1)]: Done 389 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=-1)]: Done 390 tasks      | elapsed:  6.8min
# [Parallel(n_jobs=-1)]: Done 391 tasks      | elapsed:  6.8min
# [Parallel(n_jobs=-1)]: Done 392 tasks      | elapsed:  6.8min
# [Parallel(n_jobs=-1)]: Done 393 tasks      | elapsed:  6.8min
# [Parallel(n_jobs=-1)]: Done 394 tasks      | elapsed:  6.8min
# [Parallel(n_jobs=-1)]: Done 395 tasks      | elapsed:  6.8min
# [Parallel(n_jobs=-1)]: Done 396 tasks      | elapsed:  6.9min
# [Parallel(n_jobs=-1)]: Done 397 tasks      | elapsed:  6.9min
# [Parallel(n_jobs=-1)]: Done 398 tasks      | elapsed:  7.0min
# [Parallel(n_jobs=-1)]: Done 399 tasks      | elapsed:  7.0min
# [Parallel(n_jobs=-1)]: Done 400 tasks      | elapsed:  7.0min
# [Parallel(n_jobs=-1)]: Done 401 tasks      | elapsed:  7.0min
# [Parallel(n_jobs=-1)]: Done 402 tasks      | elapsed:  7.0min
# [Parallel(n_jobs=-1)]: Done 403 tasks      | elapsed:  7.1min
# [Parallel(n_jobs=-1)]: Done 404 tasks      | elapsed:  7.1min
# [Parallel(n_jobs=-1)]: Done 405 tasks      | elapsed:  7.1min
# [Parallel(n_jobs=-1)]: Done 406 tasks      | elapsed:  7.1min
# [Parallel(n_jobs=-1)]: Done 407 tasks      | elapsed:  7.1min
# [Parallel(n_jobs=-1)]: Done 408 tasks      | elapsed:  7.2min
# [Parallel(n_jobs=-1)]: Done 409 tasks      | elapsed:  7.2min
# [Parallel(n_jobs=-1)]: Done 410 tasks      | elapsed:  7.2min
# [Parallel(n_jobs=-1)]: Done 411 tasks      | elapsed:  7.2min
# [Parallel(n_jobs=-1)]: Done 412 tasks      | elapsed:  7.2min
# [Parallel(n_jobs=-1)]: Done 413 tasks      | elapsed:  7.3min
# [Parallel(n_jobs=-1)]: Done 414 tasks      | elapsed:  7.3min
# [Parallel(n_jobs=-1)]: Done 415 tasks      | elapsed:  7.3min
# [Parallel(n_jobs=-1)]: Done 416 tasks      | elapsed:  7.3min
# [Parallel(n_jobs=-1)]: Done 417 tasks      | elapsed:  7.3min
# [Parallel(n_jobs=-1)]: Done 418 tasks      | elapsed:  7.4min
# [Parallel(n_jobs=-1)]: Done 419 tasks      | elapsed:  7.4min
# [Parallel(n_jobs=-1)]: Done 420 tasks      | elapsed:  7.4min
# [Parallel(n_jobs=-1)]: Done 421 tasks      | elapsed:  7.4min
# [Parallel(n_jobs=-1)]: Done 422 tasks      | elapsed:  7.4min
# [Parallel(n_jobs=-1)]: Done 423 tasks      | elapsed:  7.4min
# [Parallel(n_jobs=-1)]: Done 424 tasks      | elapsed:  7.5min
# [Parallel(n_jobs=-1)]: Done 425 tasks      | elapsed:  7.5min
# [Parallel(n_jobs=-1)]: Done 426 tasks      | elapsed:  7.5min
# [Parallel(n_jobs=-1)]: Done 427 tasks      | elapsed:  7.5min
# [Parallel(n_jobs=-1)]: Done 428 tasks      | elapsed:  7.5min
# [Parallel(n_jobs=-1)]: Done 429 tasks      | elapsed:  7.5min
# [Parallel(n_jobs=-1)]: Done 430 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=-1)]: Done 431 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=-1)]: Done 432 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=-1)]: Done 433 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:  7.7min
# [Parallel(n_jobs=-1)]: Done 435 tasks      | elapsed:  7.7min
# [Parallel(n_jobs=-1)]: Done 436 tasks      | elapsed:  7.7min
# [Parallel(n_jobs=-1)]: Done 437 tasks      | elapsed:  7.7min
# [Parallel(n_jobs=-1)]: Done 438 tasks      | elapsed:  7.7min
# [Parallel(n_jobs=-1)]: Done 439 tasks      | elapsed:  7.8min
# [Parallel(n_jobs=-1)]: Done 440 tasks      | elapsed:  7.8min
# [Parallel(n_jobs=-1)]: Done 441 tasks      | elapsed:  7.8min
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed:  7.8min
# [Parallel(n_jobs=-1)]: Done 443 tasks      | elapsed:  7.9min
# [Parallel(n_jobs=-1)]: Done 444 tasks      | elapsed:  7.9min
# [Parallel(n_jobs=-1)]: Done 445 tasks      | elapsed:  7.9min
# [Parallel(n_jobs=-1)]: Done 446 tasks      | elapsed:  7.9min
# [Parallel(n_jobs=-1)]: Done 447 tasks      | elapsed:  7.9min
# [Parallel(n_jobs=-1)]: Done 448 tasks      | elapsed:  7.9min
# [Parallel(n_jobs=-1)]: Done 449 tasks      | elapsed:  8.0min
# [Parallel(n_jobs=-1)]: Done 450 tasks      | elapsed:  8.0min
# [Parallel(n_jobs=-1)]: Done 451 tasks      | elapsed:  8.0min
# [Parallel(n_jobs=-1)]: Done 452 tasks      | elapsed:  8.0min
# [Parallel(n_jobs=-1)]: Done 453 tasks      | elapsed:  8.0min
# [Parallel(n_jobs=-1)]: Done 454 tasks      | elapsed:  8.1min
# [Parallel(n_jobs=-1)]: Done 455 tasks      | elapsed:  8.1min
# [Parallel(n_jobs=-1)]: Done 456 tasks      | elapsed:  8.1min
# [Parallel(n_jobs=-1)]: Done 457 tasks      | elapsed:  8.1min
# [Parallel(n_jobs=-1)]: Done 458 tasks      | elapsed:  8.2min
# [Parallel(n_jobs=-1)]: Done 459 tasks      | elapsed:  8.2min
# [Parallel(n_jobs=-1)]: Done 460 tasks      | elapsed:  8.2min
# [Parallel(n_jobs=-1)]: Done 461 tasks      | elapsed:  8.2min
# [Parallel(n_jobs=-1)]: Done 462 tasks      | elapsed:  8.3min
# [Parallel(n_jobs=-1)]: Done 463 tasks      | elapsed:  8.3min
# [Parallel(n_jobs=-1)]: Done 464 tasks      | elapsed:  8.3min
# [Parallel(n_jobs=-1)]: Done 465 tasks      | elapsed:  8.3min
# [Parallel(n_jobs=-1)]: Done 466 tasks      | elapsed:  8.4min
# [Parallel(n_jobs=-1)]: Done 467 tasks      | elapsed:  8.4min
# [Parallel(n_jobs=-1)]: Done 468 tasks      | elapsed:  8.4min
# [Parallel(n_jobs=-1)]: Done 469 tasks      | elapsed:  8.4min
# [Parallel(n_jobs=-1)]: Done 470 tasks      | elapsed:  8.5min
# [Parallel(n_jobs=-1)]: Done 471 tasks      | elapsed:  8.5min
# [Parallel(n_jobs=-1)]: Done 472 tasks      | elapsed:  8.5min
# [Parallel(n_jobs=-1)]: Done 473 tasks      | elapsed:  8.5min
# [Parallel(n_jobs=-1)]: Done 474 tasks      | elapsed:  8.6min
# [Parallel(n_jobs=-1)]: Done 475 tasks      | elapsed:  8.6min
# [Parallel(n_jobs=-1)]: Done 476 tasks      | elapsed:  8.6min
# [Parallel(n_jobs=-1)]: Done 477 tasks      | elapsed:  8.6min
# [Parallel(n_jobs=-1)]: Done 478 tasks      | elapsed:  8.7min
# [Parallel(n_jobs=-1)]: Done 479 tasks      | elapsed:  8.7min
# [Parallel(n_jobs=-1)]: Done 480 tasks      | elapsed:  8.7min
# [Parallel(n_jobs=-1)]: Done 481 tasks      | elapsed:  8.7min
# [Parallel(n_jobs=-1)]: Done 482 tasks      | elapsed:  8.7min
# [Parallel(n_jobs=-1)]: Done 483 tasks      | elapsed:  8.8min
# [Parallel(n_jobs=-1)]: Done 484 tasks      | elapsed:  8.8min
# [Parallel(n_jobs=-1)]: Done 485 tasks      | elapsed:  8.8min
# [Parallel(n_jobs=-1)]: Done 486 tasks      | elapsed:  8.8min
# [Parallel(n_jobs=-1)]: Done 487 tasks      | elapsed:  8.8min
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:  8.8min
# [Parallel(n_jobs=-1)]: Done 489 tasks      | elapsed:  8.8min
# [Parallel(n_jobs=-1)]: Done 490 tasks      | elapsed:  8.9min
# [Parallel(n_jobs=-1)]: Done 491 tasks      | elapsed:  8.9min
# [Parallel(n_jobs=-1)]: Done 492 tasks      | elapsed:  8.9min
# [Parallel(n_jobs=-1)]: Done 493 tasks      | elapsed:  8.9min
# [Parallel(n_jobs=-1)]: Done 494 tasks      | elapsed:  9.0min
# [Parallel(n_jobs=-1)]: Done 495 tasks      | elapsed:  9.0min
# [Parallel(n_jobs=-1)]: Done 496 tasks      | elapsed:  9.0min
# [Parallel(n_jobs=-1)]: Done 497 tasks      | elapsed:  9.0min
# [Parallel(n_jobs=-1)]: Done 498 tasks      | elapsed:  9.1min
# [Parallel(n_jobs=-1)]: Done 499 tasks      | elapsed:  9.1min
# [Parallel(n_jobs=-1)]: Done 500 tasks      | elapsed:  9.1min
# [Parallel(n_jobs=-1)]: Done 501 tasks      | elapsed:  9.1min
# [Parallel(n_jobs=-1)]: Done 502 tasks      | elapsed:  9.2min
# [Parallel(n_jobs=-1)]: Done 503 tasks      | elapsed:  9.2min
# [Parallel(n_jobs=-1)]: Done 504 tasks      | elapsed:  9.2min
# [Parallel(n_jobs=-1)]: Done 505 tasks      | elapsed:  9.2min
# [Parallel(n_jobs=-1)]: Done 506 tasks      | elapsed:  9.2min
# [Parallel(n_jobs=-1)]: Done 507 tasks      | elapsed:  9.2min
# [Parallel(n_jobs=-1)]: Done 508 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=-1)]: Done 509 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=-1)]: Done 510 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=-1)]: Done 511 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=-1)]: Done 512 tasks      | elapsed:  9.4min
# [Parallel(n_jobs=-1)]: Done 513 tasks      | elapsed:  9.4min
# [Parallel(n_jobs=-1)]: Done 514 tasks      | elapsed:  9.4min
# [Parallel(n_jobs=-1)]: Done 515 tasks      | elapsed:  9.4min
# [Parallel(n_jobs=-1)]: Done 516 tasks      | elapsed:  9.5min
# [Parallel(n_jobs=-1)]: Done 517 tasks      | elapsed:  9.5min
# [Parallel(n_jobs=-1)]: Done 518 tasks      | elapsed:  9.5min
# [Parallel(n_jobs=-1)]: Done 519 tasks      | elapsed:  9.5min
# [Parallel(n_jobs=-1)]: Done 520 tasks      | elapsed:  9.6min
# [Parallel(n_jobs=-1)]: Done 521 tasks      | elapsed:  9.6min
# [Parallel(n_jobs=-1)]: Done 522 tasks      | elapsed:  9.6min
# [Parallel(n_jobs=-1)]: Done 523 tasks      | elapsed:  9.6min
# [Parallel(n_jobs=-1)]: Done 524 tasks      | elapsed:  9.6min
# [Parallel(n_jobs=-1)]: Done 525 tasks      | elapsed:  9.7min
# [Parallel(n_jobs=-1)]: Done 526 tasks      | elapsed:  9.7min
# [Parallel(n_jobs=-1)]: Done 527 tasks      | elapsed:  9.7min
# [Parallel(n_jobs=-1)]: Done 528 tasks      | elapsed:  9.8min
# [Parallel(n_jobs=-1)]: Done 529 tasks      | elapsed:  9.8min
# [Parallel(n_jobs=-1)]: Done 530 tasks      | elapsed:  9.8min
# [Parallel(n_jobs=-1)]: Done 531 tasks      | elapsed:  9.8min
# [Parallel(n_jobs=-1)]: Done 532 tasks      | elapsed:  9.9min
# [Parallel(n_jobs=-1)]: Done 533 tasks      | elapsed:  9.9min
# [Parallel(n_jobs=-1)]: Done 534 tasks      | elapsed:  9.9min
# [Parallel(n_jobs=-1)]: Done 535 tasks      | elapsed:  9.9min
# [Parallel(n_jobs=-1)]: Done 536 tasks      | elapsed: 10.0min
# [Parallel(n_jobs=-1)]: Done 537 tasks      | elapsed: 10.0min
# [Parallel(n_jobs=-1)]: Done 538 tasks      | elapsed: 10.0min
# [Parallel(n_jobs=-1)]: Done 539 tasks      | elapsed: 10.0min
# [Parallel(n_jobs=-1)]: Done 540 tasks      | elapsed: 10.1min
# [Parallel(n_jobs=-1)]: Done 541 tasks      | elapsed: 10.1min
# [Parallel(n_jobs=-1)]: Done 542 tasks      | elapsed: 10.1min
# [Parallel(n_jobs=-1)]: Done 543 tasks      | elapsed: 10.1min
# [Parallel(n_jobs=-1)]: Done 544 tasks      | elapsed: 10.1min
# [Parallel(n_jobs=-1)]: Done 545 tasks      | elapsed: 10.2min
# [Parallel(n_jobs=-1)]: Done 546 tasks      | elapsed: 10.2min
# [Parallel(n_jobs=-1)]: Done 547 tasks      | elapsed: 10.2min
# [Parallel(n_jobs=-1)]: Done 548 tasks      | elapsed: 10.2min
# [Parallel(n_jobs=-1)]: Done 549 tasks      | elapsed: 10.2min
# [Parallel(n_jobs=-1)]: Done 550 tasks      | elapsed: 10.3min
# [Parallel(n_jobs=-1)]: Done 551 tasks      | elapsed: 10.3min
# [Parallel(n_jobs=-1)]: Done 552 tasks      | elapsed: 10.3min
# [Parallel(n_jobs=-1)]: Done